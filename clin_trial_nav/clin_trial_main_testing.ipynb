# %%
from textwrap import wrap
import pandas as pd
import requests
import json
from pandas import json_normalize # tranform JSON file into a pandas dataframe
import time
import re

pd.set_option('display.max_colwidth', 100)

# %%
def build_url_from_query(query):
    
    query_tokenized = query.split()
    
    field_values = ['NCTId', 'LeadSponsorName', 'BriefTitle', 'Condition', 'Phase', 'StudyType',
                    'EnrollmentCount', 'StartDate', 'PrimaryCompletionDate', 'EligibilityCriteria', 'InterventionName', 
                    'ArmGroupInterventionName', 'ArmGroupDescription', 'InterventionArmGroupLabel', 'OutcomeMeasureType', 'OutcomeMeasureTitle',
                    'OutcomeMeasureDescription', 'OutcomeMeasureTimeFrame', 'OutcomeMeasurementValue', 'OutcomeMeasureUnitOfMeasure']
    
    max_rank = 1000             # max number of items returned by the API query (max for the clinicaltrials.gov API is 1000)
    
    
    url = 'https://clinicaltrials.gov/api/query/study_fields?expr='
    
    for i, word in enumerate(query_tokenized):              # build query URL by adding all search terms and field values to the query URL, following the appropriate format
        if i == 0:
            url = url + word
        else:
            url = url + '+' + word
        
    url = url + '&fields='
    
    for i, word in enumerate(field_values):
        if i == 0:
            url = url + word
        else:
            url = url + '%2C' + word
    
    url = url + '&min_rnk=1&max_rnk=' + str(max_rank) + '&fmt=json' 
    url = url.strip()
    
    # print('\n\nQuerying up to 1,000 trials from clinicaltrials.gov with the following url...\n\n'+url+'\n\n')
    
    return url

# %%
def build_study_table(url):
        
    ## convert the clinicaltrials.gov JSON response to a pandas dataframe
    
    result = requests.get(url).json()
    
    # loop through the list and identify ONLY studies with outcome measures reported 
    # result_list = [result for result in result['StudyFieldsResponse']['StudyFields'] if result['OutcomeMeasureType']]     
    # result_list = [result for result in result['StudyFieldsResponse']['StudyFields']]
    
    result_list = [result for result in result['StudyFieldsResponse']['StudyFields'] if result['StudyType'][0] == 'Interventional']
    
    
    df_master = json_normalize(result_list[0])      # initialize dataframe using JSON result

    df_master = clean_columns(df_master)

    try:
        for study in result_list[1:]:        # concatenate each study to the dataframe to generate master dataframe
            df = json_normalize(study)
            df = clean_columns(df)
            df_master = pd.concat([df_master, df], axis=0, ignore_index=True)
    except:
        print("There was an error!")
    
#     df_master = df_master[(df_master['Phase'].str.match('.*3.*')) | (df_master['Phase'].str.match('.*2.*'))]
#     df_master = df_master[df_master['Phase'].str.match('.*3.*')].drop('Rank', 1).reset_index().drop('index', 1)
    df_master = df_master[df_master['Phase'].str.match('.*3.*')]
    
    return df_master

# %%
def clean_columns(df_master):      # this is a single-row dataframe
    for col in df_master.columns[1:]:    
        if len(df_master[col][0]) == 0:
            df_master[col] = 'Unreported'
        elif (len(df_master[col][0]) == 1) and (not re.search('Outcome.*', col)):
            df_master[col] = df_master[col][0]
        elif (len(df_master[col][0]) > 1) and (not re.search('Outcome.*', col)):
            df_master[col] = ', '.join(df_master[col][0])
    
    return df_master

# is it an outcome column?
# is length greater than 0?

# scenarios
# is any column, 0 length - confirmed
# is outcome column, any length - confirmed
# is not outcome column, 1 length - confirmed
# is not outcome column, >1 length - confirmed

# %%
def map_measure_values(df_master):      # this is a single-row dataframe
    if df_master
    num_of_outcomes = len(df_master['OutcomeMeasureType'][0])
    temp_list = []
    try:                            
        measures_per_outcome = len(df_master['OutcomeMeasurementValue'][0])//len(df_master['OutcomeMeasureTitle'][0])
    except:
        measures_per_outcome = 1
    
    beginning = 0
    increment = measures_per_outcome               # maps correct number of outcome measures reported in the study, as multiple performance values may pertain to each endpoint (i.e. value for each intervention arm + placebo)
    try:
        for i in range(num_of_outcomes):
            try:
                temp_list.append([df_master['OutcomeMeasurementValue'][0][beginning:beginning+increment]])
                beginning += increment
            except:
                print('Errors!')
        df_master['OutcomeMeasurementValue'] = temp_list
    except:
        print('Errors!')
    
    return df_master

# %%
query_term = input("Enter search query: \n")
start_time = time.process_time()
url = build_url_from_query(query_term)
print(f"Time to build url: {time.process_time()-start_time} seconds")
print(url)
# Out:
# Enter search query:
# eosinophilic asthma
# Time to build url: 0.0 seconds
# https://clinicaltrials.gov/api/query/study_fields?expr=eosinophilic+asthma&fields=NCTId%2CLeadSponsorName%2CBriefTitle%2CCondition%2CPhase%2CStudyType%2CEnrollmentCount%2CStartDate%2CPrimaryCompletionDate%2CEligibilityCriteria%2CInterventionName%2CArmGroupInterventionName%2CArmGroupDescription%2CInterventionArmGroupLabel%2COutcomeMeasureType%2COutcomeMeasureTitle%2COutcomeMeasureDescription%2COutcomeMeasureTimeFrame%2COutcomeMeasurementValue%2COutcomeMeasureUnitOfMeasure&min_rnk=1&max_rnk=1000&fmt=json

# %%
start_time = time.process_time()
study_table = build_study_table(url)
print(f"Time to build table: {time.process_time()-start_time} seconds.")
# Out:
# Time to build table: 0.6875 seconds.
# C:\Users\tenoc\AppData\Local\Temp/ipykernel_34588/1657706757.py:27: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_master = df_master[df_master['Phase'].str.match('.*3.*')].drop('Rank', 1).reset_index().drop('index', 1)

# %%
study_table
# Out:
#           NCTId  \
# 0   NCT01285323
# 1   NCT01287039
# 2   NCT01270464
# 3   NCT01290887
# 4   NCT02594332
# 5   NCT02555371
# 6   NCT02281318
# 7   NCT04305405
# 8   NCT03052725
# 9   NCT02559791
# 10  NCT04049175
# 11  NCT03470311
# 12  NCT03021304
# 13  NCT03099096
# 14  NCT01508936
# 15  NCT03557307
# 16  NCT02135692
# 17  NCT02836496
# 18  NCT04718389
# 19  NCT04718103
# 20  NCT04719832
# 21  NCT02869438
# 22  NCT03562195
# 23  NCT02049294
# 24  NCT01520051
# 25  NCT03170271
# 26  NCT05030155
# 27  NCT01842607
# 28  NCT01691508
# 29  NCT00380926
# 30  NCT03327701
# 31  NCT01463644
# 32  NCT04157335
#
#                                                       LeadSponsorName  \
# 0                      Teva Branded Pharmaceutical Products R&D, Inc.
# 1                      Teva Branded Pharmaceutical Products R&D, Inc.
# 2                      Teva Branded Pharmaceutical Products R&D, Inc.
# 3                      Teva Branded Pharmaceutical Products R&D, Inc.
# 4                                 Johannes Gutenberg University Mainz
# 5                                                     GlaxoSmithKline
# 6                                                     GlaxoSmithKline
# 7                                                         AstraZeneca
# 8                      Teva Branded Pharmaceutical Products R&D, Inc.
# 9                                                 McMaster University
# 10                                         Chiesi Farmaceutici S.p.A.
# 11                                                McMaster University
# 12                                                    GlaxoSmithKline
# 13                                                    GlaxoSmithKline
# 14                     Teva Branded Pharmaceutical Products R&D, Inc.
# 15                                                        AstraZeneca
# 16                                                    GlaxoSmithKline
# 17                                                    GlaxoSmithKline
# 18                                                    GlaxoSmithKline
# 19                                                    GlaxoSmithKline
# 20                                                    GlaxoSmithKline
# 21                                                        AstraZeneca
# 22                                                    GlaxoSmithKline
# 23                                                McMaster University
# 24  Academisch Medisch Centrum - Universiteit van Amsterdam (AMC-UvA)
# 25                                                        AstraZeneca
# 26                            Assistance Publique - Hôpitaux de Paris
# 27                                                    GlaxoSmithKline
# 28                                                    GlaxoSmithKline
# 29                         Johann Wolfgang Goethe University Hospital
# 30                                              Louis-Philippe Boulet
# 31                                                McMaster University
# 32                                                        AstraZeneca
#
#                                                                                              BriefTitle  \
# 0        A Study to Evaluate the Efficacy and Safety of Reslizumab in Patients With Eosinophilic Asthma
# 1   A Study to Evaluate the Efficacy and Safety of Reslizumab (3.0 mg/kg) in the Reduction of Clinic...
# 2   A Study to Evaluate the Efficacy and Safety of Reslizumab (0.3 or 3.0 mg/kg) as Treatment for Pa...
# 3   Open-Label Extension Study to Evaluate the Long-Term Safety and Efficacy of Reslizumab (3.0 mg/k...
# 4   Effects of Mepolizumab Compared to Placebo on Airway Physiology in Patients With Eosinophilic As...
# 5         Cessation Versus Continuation of Long-term Mepolizumab in Severe Eosinophilic Asthma Patients
# 6   Efficacy and Safety Study of Mepolizumab Adjunctive Therapy in Participants With Severe Eosinoph...
# 7          PK/PD and Long Term Safety Study of Benralizumab in Children With Severe Eosinophilic Asthma
# 8           A Study of Reslizumab in Patients 12 Years of Age and Older With Severe Eosinophilic Asthma
# 9        Anti-Interleukin-5 (IL5) Monoclonal Antibody (MAb) in Prednisone-dependent Eosinophilic Asthma
# 10             Efficacy and Safety of CHF 6532 in Patients With Uncontrolled Severe Eosinophilic Asthma
# 11          Benralizumab in Patients With Inadequate Response to Anti-IL5 Monoclonal Antibody Therapies
# 12                                                    Study of Mepolizumab Safety Syringe in Asthmatics
# 13                                                      Study of Mepolizumab Autoinjector in Asthmatics
# 14  Study to Evaluate the Efficacy and Safety of Reslizumab Treatment in Patients With Moderate to S...
# 15  Study to Evaluate Efficacy and Safety of Benralizumab in Reducing Oral Corticosteroid Use in Adu...
# 16     A Phase 3a, Repeat Dose, Open-label, Long-term Safety Study of Mepolizumab in Asthmatic Subjects
# 17    Efficacy and Safety Study of Mepolizumab in Subjects With Severe Hypereosinophilic Syndrome (HES)
# 18  A Study of GSK3511294 (Depemokimab) Compared With Mepolizumab or Benralizumab in Participants Wi...
# 19  A Study of GSK3511294 (Depemokimab) in Participants With Severe Asthma With an Eosinophilic Phen...
# 20  Placebo-controlled Efficacy and Safety Study of GSK3511294 (Depemokimab) in Participants With Se...
# 21  A Study to Evaluate the Onset of Effect and Time Course of Change in Lung Function With Benraliz...
# 22                            A Safety and Efficacy Study of Mepolizumab in Subjects With Severe Asthma
# 23  Study of the Steroid Sparing Effect of Xolair (Omalizumab) in Patients With Persistent Eosinophi...
# 24                                    Mepolizumab Treatment for Rhinovirus-induced Asthma Exacerbations
# 25  A Study of the Safety and Effectiveness of Benralizumab to Treat Patients With Severe Uncontroll...
# 26  Study of Mepolizumab-based Regimen Compared to Conventional Therapeutic Strategy in Patients Wit...
# 27                           A Study to Determine Long-term Safety of Mepolizumab in Asthmatic Subjects
# 28                          Mepolizumab Steroid-Sparing Study in Subjects With Severe Refractory Asthma
# 29                                                       Fish Oil and Asthma in House Dust Mite Allergy
# 30                                   The Effect of Benralizumab on Exercise-induced Bronchoconstriction
# 31            Mepolizumab in Chronic Obstructive Pulmonary Diseases (COPD) With Eosinophilic Bronchitis
# 32  Efficacy and Safety Study of Benralizumab in Patient With Eosinophilic Chronic Rhinosinusitis Wi...
#
#                                                                          Condition  \
# 0                                                              Eosinophilic Asthma
# 1                                                              Eosinophilic Asthma
# 2                                                              Eosinophilic Asthma
# 3                                                              Eosinophilic Asthma
# 4                                                                           Asthma
# 5                                                                           Asthma
# 6                                                                           Asthma
# 7                                                       Severe Uncontrolled Asthma
# 8                                                              Eosinophils, Asthma
# 9                                Severe Persistent Asthma, Eosinophilic Bronchitis
# 10                                                            Asthma; Eosinophilic
# 11                                 Severe Prednisone Dependent Eosinophilic Asthma
# 12                                                                          Asthma
# 13                                                                          Asthma
# 14                                                             Eosinophilic Asthma
# 15                                                                          Asthma
# 16                                                                          Asthma
# 17                                                      Hypereosinophilic Syndrome
# 18                                                                          Asthma
# 19                                                                          Asthma
# 20                                                                          Asthma
# 21                                                                          Asthma
# 22                                                                          Asthma
# 23             Steroid and/or Prednisone Dependent Asthma, Eosinophilic Bronchitis
# 24                                                         Asthma, Viral Infection
# 25                                                                          Asthma
# 26                                   Eosinophilic Granulomatosis With Polyangiitis
# 27                                                                          Asthma
# 28                                                                          Asthma
# 29                Allergic Asthma, Bronchial Inflammation, House Dust Mite Allergy
# 30                                                        Asthma, Exercise-Induced
# 31  Chronic Obstructive Pulmonary Diseases, Chronic Airways Limitation, Bronchitis
# 32                                                                 Nasal Polyposis
#
#                Phase       StudyType EnrollmentCount          StartDate  \
# 0            Phase 3  Interventional             464         March 2011
# 1            Phase 3  Interventional             489         April 2011
# 2            Phase 3  Interventional             315      February 2011
# 3            Phase 3  Interventional            1052          June 2011
# 4            Phase 3  Interventional              29  November 17, 2015
# 5            Phase 3  Interventional             306    January 7, 2016
# 6            Phase 3  Interventional             556  December 11, 2014
# 7            Phase 3  Interventional              30  November 21, 2019
# 8            Phase 3  Interventional             391     March 10, 2017
# 9   Phase 2, Phase 3  Interventional              10       October 2015
# 10           Phase 3  Interventional             810    August 28, 2019
# 11           Phase 3  Interventional              20     April 26, 2018
# 12           Phase 3  Interventional              56   February 1, 2017
# 13           Phase 3  Interventional             159        May 4, 2017
# 14           Phase 3  Interventional             511      February 2012
# 15           Phase 3  Interventional             598     August 1, 2018
# 16           Phase 3  Interventional             339       May 29, 2014
# 17           Phase 3  Interventional             108      March 7, 2017
# 18           Phase 3  Interventional            1700   January 26, 2021
# 19           Phase 3  Interventional             375  February 25, 2021
# 20           Phase 3  Interventional             375     March 17, 2021
# 21           Phase 3  Interventional             233   November 9, 2016
# 22           Phase 3  Interventional             300    August 29, 2018
# 23  Phase 2, Phase 3  Interventional              11         March 2014
# 24           Phase 3  Interventional              48       January 2012
# 25           Phase 3  Interventional             660       July 7, 2017
# 26           Phase 3  Interventional             100      December 2021
# 27           Phase 3  Interventional             651       May 27, 2013
# 28           Phase 3  Interventional             135       October 2012
# 29  Phase 2, Phase 3  Interventional              23         April 2004
# 30           Phase 3  Interventional              40      December 2017
# 31           Phase 3  Interventional              19       January 2012
# 32           Phase 3  Interventional             276  November 25, 2019
#
#    PrimaryCompletionDate  \
# 0             April 2014
# 1          December 2013
# 2         September 2013
# 3           January 2015
# 4           May 22, 2017
# 5          July 24, 2019
# 6          June 10, 2016
# 7       October 31, 2022
# 8      February 22, 2018
# 9             April 2017
# 10      October 19, 2020
# 11            April 2022
# 12        August 8, 2017
# 13     November 30, 2017
# 14           August 2013
# 15        April 16, 2021
# 16       October 5, 2017
# 17        August 8, 2019
# 18     December 15, 2023
# 19       August 23, 2023
# 20       October 3, 2023
# 21        August 1, 2018
# 22     November 30, 2022
# 23        September 2017
# 24         December 2013
# 25    September 25, 2019
# 26         December 2024
# 27        March 13, 2015
# 28         December 2013
# 29            Unreported
# 30         December 2019
# 31           August 2015
# 32          June 2, 2023
#
#                                                                                     EligibilityCriteria  \
# 0   Inclusion Criteria:\n\nThe patient is male or female, 12 through 75 years of age, with a previou...
# 1   Inclusion Criteria:\n\nThe patient is male or female, 12 through 75 years of age, with a previou...
# 2   Inclusion Criteria:\n\nThe patient is male or female, 12 through 75 years of age, with a previou...
# 3   Inclusion Criteria:\n\nWritten informed consent is obtained.\nPatient must have completed treatm...
# 4   Inclusion Criteria:\n\nPatients must be able to give written informed consent prior to participa...
# 5   Inclusion Criteria:\n\nInformed Consent: Prior to commencing any study related activities, subje...
# 6   Inclusion Criteria:\n\nAge: At least 12 years of age at the time of signing the informed consent...
# 7   Inclusion Criteria:\n\nPatients are eligible to be included in the study only if all of the foll...
# 8   Inclusion Criteria:\n\n• Patient with eosinophilic asthma who completed the treatment period of ...
# 9   Inclusion Criteria:\n\nInformed consent Prior to the beginning of the study, patients must be wi...
# 10  Inclusion Criteria:\n\nMale or female subjects aged ≥12 years and ≤75 years with a diagnosis of ...
# 11  Inclusion Criteria:\n\nInformed consent Prior to the beginning of the study, patients must be wi...
# 12  Inclusion Criteria:\n\nAge: At least 12 years of age inclusive, at the time of signing the infor...
# 13  Inclusion Criteria:\n\nAge: At least 12 years of age inclusive, at the time of signing the infor...
# 14  Inclusion criteria:\n\nPatients are included in the study if all of the following criteria are m...
# 15  Inclusion Criteria:\n\nPeripheral blood eosinophil count of ≥150 cells/μL assessed by central la...
# 16  Inclusion Criteria:\n\nInformed Consent: Prior to commencing any study related activities, subje...
# 17  Inclusion Criteria:\n\nCapable of giving signed informed consent/assent which includes complianc...
# 18  Key inclusion criteria for study:\n\nAdult and adolescent participants more than or equal to (>=...
# 19  Key inclusion criteria for study:\n\nAdults and adolescents >=12 years of age, at the time of si...
# 20  Key inclusion Criteria:\n\nAdults and adolescents greater than or equal to (>=)12 years of age, ...
# 21  Inclusion criteria\n\nWritten informed consent for study participation must be obtained prior to...
# 22  Inclusion Criteria:\n\nSubjects who will be able to give written informed consent prior to parti...
# 23  Inclusion criteria\n\nConfirmed asthma within the past 2 years (12% bronchodilator reversibility...
# 24  Inclusion Criteria:\n\nAge between 18 - 50 years\nHistory of episodic chest tightness and wheezi...
# 25  Inclusion Criteria:\n\nFemale and male patients aged 18 to 75 years inclusively at the time of V...
# 26  Inclusion Criteria:\n\nPatients with a diagnosis of EGPA independently of ANCA status,\nPatients...
# 27  Inclusion Criteria:\n\nFrench subjects: In France, a subject will be eligible for inclusion in t...
# 28  Inclusion Criteria:\n\nInformed Consent and Study Compliance: Subjects must be able to give writ...
# 29  Inclusion Criteria:\n\nallergic sensitization to house dust mite as proven by skin test and spec...
# 30  Inclusion Criteria:\n\nWritten informed consent for study participants must be obtained prior to...
# 31  Inclusion Criteria:\n\nDiagnosis: An established clinical history of COPD in accordance with the...
# 32  Inclusion criteria:\n\nFemale or male patients aged 18 to 75 years inclusive\nStable Intranasal ...
#
#                                                                                        InterventionName  \
# 0                                                                                   Reslizumab, Placebo
# 1                                                                                   Reslizumab, Placebo
# 2                                                                                   Reslizumab, Placebo
# 3                                                                                            Reslizumab
# 4                                                                                  Mepolizumab, Placebo
# 5                                                                            Mepolizumab 100mg, Placebo
# 6                                                                             Mepolizumab, Placebo, SOC
# 7                                                                                          Benralizumab
# 8                                                                                            reslizumab
# 9                                                                                   Reslizumab, Placebo
# 10                                                   Treatment A, Treatment B, Treatment C, Treatment D
# 11                                                                                Benralizumab, Placebo
# 12                                                                                          Mepolizumab
# 13                                                                                          Mepolizumab
# 14                                                                                  Reslizumab, Placebo
# 15                                                                                         Benralizumab
# 16                                                                                     Mepolizumab, SOC
# 17  Mepolizumab 300 mg, Placebo matching mepolizumab, Active OCS capsules (5 mg prednisolone or pred...
# 18  GSK3511294 (Depemokimab), Mepolizumab, Benralizumab, Placebo, Standard of care (SoC), Pre-filled...
# 19                              GSK3511294 (Depemokimab), Placebo, Standard of Care, Pre-filled Syringe
# 20                              GSK3511294 (Depemokimab), Placebo, Standard of care, Pre-filled Syringe
# 21                                                                                Benralizumab, Placebo
# 22                                                      Mepolizumab 100 milligrams, Placebo, Salbutamol
# 23                                                                         Omalizumab (Xolair), Placebo
# 24                                                                                 Mepolizumab, Placebo
# 25                                                                     Benralizumab (Medi-563), Placebo
# 26                                                  Mepolizumab, cyclophosphamide/azathioprine, Placebo
# 27                                                                                          Mepolizumab
# 28                                                  Mepolizumab, Placebo, OCS (prednisone/prednisolone)
# 29                                                              polyunsatturated fatty acids (fish oil)
# 30                                                                                         Benralizumab
# 31                                                                                 Mepolizumab, placebo
# 32                                                                  Benralizumab 30 mg, Matched placebo
#
#                                                                                ArmGroupInterventionName  \
# 0                                                                       Drug: Placebo, Drug: Reslizumab
# 1                                                                       Drug: Placebo, Drug: Reslizumab
# 2                                                     Drug: Placebo, Drug: Reslizumab, Drug: Reslizumab
# 3                                                                                      Drug: Reslizumab
# 4                                                                      Drug: Mepolizumab, Drug: Placebo
# 5                           Biological: Mepolizumab 100mg, Biological: Mepolizumab 100mg, Drug: Placebo
# 6                                          Biological: Mepolizumab, Drug: SOC, Drug: Placebo, Drug: SOC
# 7                                                                Drug: Benralizumab, Drug: Benralizumab
# 8                                                                                      Drug: reslizumab
# 9                                                                 Biological: Reslizumab, Drug: Placebo
# 10                           Drug: Treatment A, Drug: Treatment B, Drug: Treatment C, Drug: Treatment D
# 11                                                        Biological: Benralizumab, Biological: Placebo
# 12                                                                                    Drug: Mepolizumab
# 13                                                                                    Drug: Mepolizumab
# 14                                                                      Drug: Placebo, Drug: Reslizumab
# 15                                                                             Biological: Benralizumab
# 16                                                                   Biological: Mepolizumab, Drug: SOC
# 17  Drug: Mepolizumab 300 mg, Drug: Active OCS capsules (5 mg prednisolone or prednisone), Drug: Pla...
# 18  Biological: GSK3511294 (Depemokimab), Biological: Placebo, Drug: Standard of care (SoC), Device:...
# 19  Biological: GSK3511294 (Depemokimab), Drug: Standard of Care, Device: Pre-filled Syringe, Biolog...
# 20  Biological: GSK3511294 (Depemokimab), Drug: Standard of care, Device: Pre-filled Syringe, Drug: ...
# 21                                                                   Drug: Benralizumab, Other: Placebo
# 22                  Drug: Mepolizumab 100 milligrams, Drug: Salbutamol, Drug: Placebo, Drug: Salbutamol
# 23                                                       Drug: Placebo, Biological: Omalizumab (Xolair)
# 24                                                                     Drug: Mepolizumab, Drug: Placebo
# 25                                                         Drug: Benralizumab (Medi-563), Drug: Placebo
# 26  Drug: Mepolizumab, Drug: Placebo, Drug: Mepolizumab, Drug: Placebo, Drug: cyclophosphamide/azath...
# 27                                                                              Biological: Mepolizumab
# 28  Drug: Mepolizumab, Drug: OCS (prednisone/prednisolone), Drug: Placebo, Drug: OCS (prednisone/pre...
# 29                                                                                           Unreported
# 30                                                               Drug: Benralizumab, Drug: Benralizumab
# 31                                                                     Drug: Mepolizumab, Drug: placebo
# 32                                          Biological: Benralizumab 30 mg, Biological: Matched placebo
#
#                                                                                     ArmGroupDescription  \
# 0   Placebo administered intravenously once every 4 weeks ( +-7 days) for a total of 13 doses., Resl...
# 1   Placebo administered intravenously once every 4 weeks ( +-7 days) for a total of 13 doses., Resl...
# 2   Placebo administered intravenously (iv) once every 4 weeks, for a total of 4 doses., 0.3 mg/kg, ...
# 3   Reslizumab 3.0 mg/kg administered intravenously once every 4 weeks ( +-7 days) for up to 24 months.
# 4   100 mg SC every 4 weeks for 13 injections, Amount of Placebo corresponding to mepolizumab dose S...
# 5   There will be 4 parts during the study. Part A will be Variable Open-Label Run-in (maximum up to...
# 6   Participants will receive Mepolizumab 100 mg subcutaneously (SC) into the upper arm or thigh eve...
# 7                                                        Below 35 kilos, Greater than/equal to 35 kilos
# 8   Reslizumab was administered as 110 mg subcutaneous (sc) injection in the thigh, abdomen, or uppe...
# 9   All study participants will receive 2 monthly doses of placebo followed by 4 monthly doses of IV...
# 10  Administration of CHF 6532 Dose #1, Administration of CHF 6532 Dose #2, Administration of CHF 65...
# 11  Benralizumab 30mg in 1mL subcutaneously, Matched placebo (1mL) to active Benralizumab subcutaneo...
# 12  Subjects will receive 3 doses of 100 mg mepolizumab, liquid drug product in safety syringe, subc...
# 13  Three doses of mepolizumab liquid drug product in autoinjector will be self-administered by the ...
# 14  Placebo intravenous injection every 4 weeks for a total of 4 doses., Reslizumab intravenous inje...
# 15                                                                  Benralizumab subcutaneous injection
# 16  All subjects will receive mepolizumab 100mg administered SC into the upper arm or thigh approxim...
# 17  Enrolled subjects will receive either mepolizumab 300 mg or placebo subcutaneous (SC) every 4 we...
# 18  Participants will receive GSK3511294 (Depemokimab) plus placebo treatment matching the active co...
# 19  Participants will receive GSK3511294 (Depemokimab) during the study. All participants will conti...
# 20  Participants will be administered GSK3511294 (Depemokimab) along with SoC., Participants will be...
# 21                        Benralizumab administered subcutaneously, Placebo administered subcutaneously
# 22  Eligible subjects will randomized in 1:1 ratio to Mepolizumab group or Placebo group. Subjects i...
# 23  Dosage/frequency is dependent on body weight (kg) and baseline blood IgE level., 0.9% normal sal...
# 24                                                                                           Unreported
# 25  Benralizumab (Medi563) Administered subcutaneously at Visit 4 (day 0), Visit 6 (day 28 +/- 3 day...
# 26  Mepolizumab 300mg every 4 weeks until D336, Placebo of Mepolizumab every 4 weeks until D336, Mep...
# 27  Subjects will receive 100 mg of Mepolizumab (in polypropylene syringe) injected subcutaneously (...
# 28  Mepolizumab 100 mg subcutaneous once every 4 weeks upto Week 20, Placebo subcutaneous once every...
# 29                                                                                           Unreported
# 30  Subjects will receive benralizumab 30 mg (subcutaneous) every 4 weeks for three doses followed b...
# 31                                                                                           Unreported
# 32                        Benralizumab administered subcutaneously, Placebo administered subcutaneously
#
#                                                                               InterventionArmGroupLabel  \
# 0                                                                         Reslizumab 3.0 mg/kg, Placebo
# 1                                                                         Reslizumab 3.0 mg/kg, Placebo
# 2                                               Reslizumab - 0.3 mg/kg, Reslizumab - 3.0 mg/kg, Placebo
# 3                                                                                  Reslizumab 3.0 mg/kg
# 4                                                                                  Mepolizumab, Placebo
# 5                                                      Arm Mepolizumab 100 mg, Arm Placebo, Arm Placebo
# 6                                                Mepolizumab SC, Placebo SC, Mepolizumab SC, Placebo SC
# 7                                                                                        Dose 1, Dose 2
# 8                                                                                     reslizumab 110 mg
# 9                                                                Study participants, Study participants
# 10                                                   Treatment A, Treatment B, Treatment C, Treatment D
# 11                                                                                Benralizumab, Placebo
# 12                                              Mepolizumab SC 100 mg/milliliter (mL) in Safety syringe
# 13                                                Mepolizumab SC 100 mg/milliliter (mL) in autoinjector
# 14                                                                        Reslizumab 3.0 mg/kg, Placebo
# 15                                                                                         Benralizumab
# 16                                                               Mepolizumab 100 mg, Mepolizumab 100 mg
# 17                                     Mepolizumab, Placebo, Mepolizumab, Placebo, Mepolizumab, Placebo
# 18  Participants receiving GSK3511294 (Depemokimab) plus placebo matching prior anti-IL-5/5R treatme...
# 19  Participants receiving GSK3511294 (Depemokimab), Participants receiving Placebo, Participants re...
# 20  Participants receiving GSK3511294 (Depemokimab), Participants receiving placebo, Participants re...
# 21                                                                        Benralizumab arm, Placebo arm
# 22  Subjects receiving Mepolizumab, Subjects receiving Placebo, Subjects receiving Mepolizumab, Subj...
# 23                                                         Placebo (Normal Saline), Omalizumab (Xolair)
# 24                                                                                  Mepolizumab, Saline
# 25                                                                     Benralizumab (Medi-563), Placebo
# 26  Patients with FFS=0 - Mepolizumab, Patients with FFS≥1 - Mepolizumab, Patients with FFS≥1 - Plac...
# 27                                                                                      Mepolizumab Arm
# 28                                                           Mepolizumab, Placebo, Mepolizumab, Placebo
# 29                                                                                           Unreported
# 30                                                                                Experimental, Placebo
# 31                                                                                 mepolizumab, placebo
# 32                                                                                Benralizumab, Placebo
#
#                                                                                      OutcomeMeasureType  \
# 0   [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 1   [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 2   [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 3   [Primary, Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Primary, Secondary, Se...
# 4                                                                                            Unreported
# 5                                                            [Primary, Secondary, Secondary, Secondary]
# 6                                                            [Primary, Secondary, Secondary, Secondary]
# 7                                                                                            Unreported
# 8   [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12                                                                                 [Primary, Secondary]
# 13                                                             [Primary, Primary, Secondary, Secondary]
# 14  [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 15                                                                                           Unreported
# 16  [Primary, Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, ...
# 17                                                [Primary, Secondary, Secondary, Secondary, Secondary]
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [Primary, Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, ...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 26                                                                                           Unreported
# 27  [Primary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary, Secondary...
# 28                                                [Primary, Secondary, Secondary, Secondary, Secondary]
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
#
#                                                                                     OutcomeMeasureTitle  \
# 0   [Frequency of Clinical Asthma Exacerbations (CAEs) During 12 Months of Treatment, Change From Ba...
# 1   [Frequency of Clinical Asthma Exacerbations (CAEs) During 12 Months of Treatment, Change From Ba...
# 2   [Change From Baseline In Forced Expiratory Volume In 1 Second (FEV1) Over 16 Weeks Using Mixed M...
# 3   [Participants With Treatment-Emergent Adverse Events, Participants With Treatment-Emergent Poten...
# 4                                                                                            Unreported
# 5   [Percentage of Participants With First Clinically Significant Exacerbation in Part C, Ratio to B...
# 6   [Mean Change From Baseline (BL) in St. George's Respiratory Questionnaire (SGRQ) Score at Week 2...
# 7                                                                                            Unreported
# 8   [Participants With Treatment-Emergent Adverse Events (TEAEs), Participants With Potentially Clin...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12  [Percentage of Participants With Successful Self-administration of Their Observed Third Dose at ...
# 13  [Percentage of Participants With Successful Self-administration of Their Observed Third Dose at ...
# 14  [Change From Baseline in Forced Expiratory Volume in 1 Second (FEV1) at Week 16 in Full Analysis...
# 15                                                                                           Unreported
# 16  [Annualized Rate of On-treatment Exacerbations Per Year, Number of Participants With Any On-trea...
# 17  [Percentage of Participants Who Experienced an HES Flare or Who Withdrew From the Study During t...
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [Change From Baseline (Visit 4) to Day 28 (Visit 8), Day 56 (Visit 9), and Day 84 (Visit 10) in ...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [Annualized Rate of Asthma Exacerbations Over the Treatment Period (up to Week 24), Change From ...
# 26                                                                                           Unreported
# 27  [Number of Participants With Adverse Events (AEs) Including Both Systemic (i.e. Allergic/Immunog...
# 28  [Number of Participants With the Indicated Percent Reduction From Baseline in Oral Corticosteroi...
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
#
#                                                                               OutcomeMeasureDescription  \
# 0   [An exacerbation event was considered a CAE if the patient met either or both of the criteria li...
# 1   [An exacerbation event was considered a CAE if the patient met either or both of the criteria li...
# 2   [FEV1 is a standard measurement of air movement in the lungs of patients with asthma obtained fr...
# 3   [An adverse event was defined in the protocol as any untoward medical occurrence that develops o...
# 4                                                                                            Unreported
# 5   [Clinically significant exacerbation was defined as worsening of asthma which requires use of sy...
# 6   [SGRQ consisted of 50 questions (scored from 0 to 100 where 0 indicates best and 100 indicates w...
# 7                                                                                            Unreported
# 8   [An adverse event is any untoward medical occurrence, regardless of whether it has a causal rela...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12  [During the clinic visits the Investigator or designee evaluated if the participants were able t...
# 13  [Due to differences in the labelling requirements among regulatory authorities around the world,...
# 14  [FEV1 is a standard measurement of air movement in the lungs of patients with asthma. It is the ...
# 15                                                                                           Unreported
# 16  [Exacerbations are defined as the worsening of asthma which requires use of systemic corticoster...
# 17  [Percentage of participants who experienced >=1 HES flare during the 32-Week treatment period or...
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [The average over the mean differences between benralizumab and placebo for change from baseline...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [An asthma exacerbation was defined as a worsening of asthma that led to any of the following:\n...
# 26                                                                                           Unreported
# 27  [AEs were collected from the Baseline visit until the follow-up visit (approx. 12 weeks post-las...
# 28  [Baseline (BL) dose was the prescribed optimized prednisone/prednisolone dose following the OCS ...
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
#
#                                                                                 OutcomeMeasureTimeFrame  \
# 0   [Day 1 to Month 12, Day 1 (baseline, pre-dose), Week 16, Day 1 (baseline, pre-dose), Weeks 4, 8,...
# 1   [Day 1 to Week 52, Day 1 (baseline, pre-dose), Weeks 4, 8, 12 and 16, Day 1 (baseline, pre-dose)...
# 2   [Day 0 (baseline, pre-dose), Weeks 4, 8, 12 and 16, Day 1 (baseline, pre-dose), Weeks 4, 8, 12, ...
# 3   [Day 1 (post-dose) to Week 65. The endpoint for adverse events was the last postbaseline observa...
# 4                                                                                            Unreported
# 5   [Weeks 12, 24, 36 and 52, Baseline and Weeks 12, 24, 36 and 52, Baseline and Weeks 12, 24, 36 an...
# 6   [Baseline and Week 24, Baseline and Week 24, Baseline (Visit 2-latest pre-dose assessment) and W...
# 7                                                                                            Unreported
# 8   [Day 1 to up to Day 269; for participants who discontinued early for reasons other than study te...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12                                                                                     [Week 8, Week 4]
# 13                                                                     [Week 8, Week 8, Week 4, Week 4]
# 14  [Baseline (Day 1), Week 16, Baseline (Day 1), Weeks 4, 8, 12, 16, Baseline (Day 1), Weeks 4, 8, ...
# 15                                                                                           Unreported
# 16  [Baseline (Week 0) to Week 172, Baseline (Week 0) to Week 172, Baseline (Week 0) to Week 168, Ba...
# 17  [Up to Week 32, Week 20 to Week 32, Weeks 4, 8, 12, 16, 20, 24, 28 and 32, Up to Week 32, Baseli...
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [From first IP dose to Day 84, From first IP dose to Day 84, From first IP dose to Day 84, From ...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [Baseline (Week 0) up to Week 24, Baseline (Week 0) and Week 24, Baseline (Week 0) and Week 24, ...
# 26                                                                                           Unreported
# 27  [From Baseline visit until the follow-up visit (approximately [approx.] week 60 [12 weeks post-l...
# 28  [Baseline; Weeks 20 to 24, Baseline; Weeks 20 to 24, Weeks 20 to 24, Weeks 20 to 24, Baseline; W...
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
#
#                                                                                 OutcomeMeasurementValue  \
# 0   [2.115, 0.859, 0.122, 0.223, 0.094, 0.187, 0.777, 0.987, -0.660, -0.857, NA, NA, 0.080, 0.115, -...
# 1   [1.804, 0.904, 0.110, 0.248, 0.695, 0.933, -0.676, -0.941, 34.9, NA, 0.109, 0.167, -0.36, -0.64,...
# 2   [0.126, 0.242, 0.286, 0.172, 0.220, 0.301, -0.145, -0.114, 0.089, 0.8, 4.9, 7.5, 0.8, 5.5, 6.7, ...
# 3   [359, 385, 744, 31, 47, 78, 49, 41, 90, 6, 12, 18, 33, 45, 78, 1, 2, 3, 344, 367, 711, 78, 82, 1...
# 4                                                                                            Unreported
# 5   [31.8, 20.2, 49.3, 32.3, 56.0, 40.3, 60.7, 47.1, 6.03, 1.16, 6.58, 1.03, 6.48, 1.20, 6.17, 1.00,...
# 6                                                          [-7.9, -15.6, 56, 176, 55, 73, -0.40, -0.80]
# 7                                                                                            Unreported
# 8   [102, 114, 7, 6, 5, 11, 0, 0, 2, 0, 0, 0, 8, 5, 1, 0, 4, 2, 2, 0, 0, 1, 2, 0, 1, 1, 0, 1, 12, 10...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12                                                                                           [100, 100]
# 13                                                                                     [99, 98, 98, 96]
# 14  [-0.2778, 0.0229, 0.175, 0.251, -0.614, -0.737, -0.2944, 0.0271, 0.164, 0.224, 0.199, 0.249, 0.1...
# 15                                                                                           Unreported
# 16  [0.93, 315, 84, -0.16, -0.15, -0.21, -0.17, -0.18, -0.08, -0.03, -0.12, -0.06, -0.01, -0.09, 0.3...
# 17  [56, 28, 35, 17, 7.4, 5.6, 14.9, 7.4, 26.2, 9.3, 33.8, 13.0, 41.3, 13.0, 48.9, 14.8, 50.8, 20.5,...
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [0.21, 0.132, 0.22, 0.203, 0.209, 0.149, -0.415, -0.208, -88.55, 11.55, 0.104, 0.081, 0.125, 0.0...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [0.94, 1.86, -23.06, -14.94, 0.30, 0.14, -1.47, -1.01, 123, 107, 27.17, 7.06, 16.47, -6.61, 17.7...
# 26                                                                                           Unreported
# 27  [558, 119, 94, 1, 0, 31, 615, 0, 31, 0.93, -0.09, -0.11, -0.05, -0.10, -0.09, 0.20, 67, 50, 29, ...
# 28       [7, 16, 5, 12, 10, 9, 7, 7, 37, 25, 22, 37, 44, 32, 21, 37, 45, 32, 5, 10, 61, 59, 0.0, -50.0]
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
#
#                                                                             OutcomeMeasureUnitOfMeasure
# 0   [CAEs in 52 weeks, liters, liters, units on a scale, units on a scale, weeks, units on a scale, ...
# 1   [CAEs in 52 weeks, liters, units on a scale, units on a scale, weeks, units on a scale, puffs/da...
# 2   [liters, liters, liters/second, percentage of predicted FEV1, units on a scale, units on a scale...
# 3   [participants, participants, liters, percentage of predicted FEV1, liters, liters/second, # puff...
# 4                                                                                            Unreported
# 5           [Percentage of participants, Ratio, Percentage of participants, Percentage of participants]
# 6                  [Scores on a scale, Milliliters (mL), Percentage of participants, Scores on a scale]
# 7                                                                                            Unreported
# 8   [Participants, Participants, Participants, Participants, Participants, CAEs / year, CAEs / year,...
# 9                                                                                            Unreported
# 10                                                                                           Unreported
# 11                                                                                           Unreported
# 12                                             [Percentage of participants, Percentage of participants]
# 13  [Percentage of participants, Percentage of Participants, Percentage of participants, Percentage ...
# 14  [FEV1 liters/ eosinophils 10^9/liter, liters, units on a scale, FEV1 liters/ eosinophils 10^9/li...
# 15                                                                                           Unreported
# 16  [Exacerbations per year, Participants, Scores on a scale, Milliliter, Participants, Participants...
# 17  [Percentage of participants, Percentage of participants, Probability expressed as percentage, Fl...
# 18                                                                                           Unreported
# 19                                                                                           Unreported
# 20                                                                                           Unreported
# 21  [Liter, Liter, Percent change, Liter, Liter, Percentage of Participants, Score on a scale, Score...
# 22                                                                                           Unreported
# 23                                                                                           Unreported
# 24                                                                                           Unreported
# 25  [Events/year, Scores on a scale, Liters (L), Scores on a scale, Participants, L/minute, Scores o...
# 26                                                                                           Unreported
# 27  [Participants, Participants, Exacerbations per year, Score on scale, Milliliters (mL), Participa...
# 28           [Participants, Participants, Participants, Participants, Percentage reduction in OCS dose]
# 29                                                                                           Unreported
# 30                                                                                           Unreported
# 31                                                                                           Unreported
# 32                                                                                           Unreported
